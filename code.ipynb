# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# 1. Data preproccessing

# %%
df=pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df=df.drop('Id',axis=1)

# %%
f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df['SalePrice'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of price')
# Out:
# C:\Users\NoteBook\AppData\Local\Temp\ipykernel_8788\2992819048.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SalePrice'],bins=50,color='r',ax=ax)
# Text(0.5, 1.0, 'Distribution of price')

# %% [markdown]
# 1.1 Remove columns with more than 50% missing data

# %%
columns_isnull=[i for i in df.columns if df[i].isnull().sum()>600]

print(columns_isnull)
df.drop(columns=columns_isnull,inplace=True)
# Out:
# ['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %% [markdown]
# 1.2 Remove columns that have more than 80% similarity data

# %%
cols_same=[]
for col in df.columns:
    most=df[col].mode()[0]
    count_col=(df[col]==most).sum()
    if count_col / len(df)>0.8:
        cols_same.append(col)

print(cols_same)

df.drop(columns=cols_same,inplace=True)
# Out:
# ['Street', 'LandContour', 'Utilities', 'LandSlope', 'Condition1', 'Condition2', 'BldgType', 'RoofMatl', 'ExterCond', 'BsmtCond', 'BsmtFinType2', 'BsmtFinSF2', 'Heating', 'CentralAir', 'Electrical', 'LowQualFinSF', 'BsmtHalfBath', 'KitchenAbvGr', 'Functional', 'GarageQual', 'GarageCond', 'PavedDrive', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'SaleType', 'SaleCondition']

# %% [markdown]
# 1.3 Encoding data

# %%
categorical_col = []
for column in df.columns:
    if df[column].dtype == object:
        categorical_col.append(column)
categorical_col
# Out:
# []

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
for col in categorical_col:
    df[col] = label.fit_transform(df[col])

# %% [markdown]
# 1.4 Identifying columns with missing data and filling them

# %%
columns_null=[i for i in df.columns if df[i].isnull().sum()>0]
print(columns_null)
df.fillna(method='ffill',inplace=True)
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
# C:\Users\NoteBook\AppData\Local\Temp\ipykernel_10220\449513654.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)

# %% [markdown]
# 1.4 Boxcox

# %%
from scipy.stats import boxcox
y_bc,lam, ci= boxcox(df['SalePrice'],alpha=0.05)
ci,lam
# Out:
# ((-0.1678292542172084, 0.014467035560839978), -0.07692391328663316)

# %% [markdown]
# 1.5 Log transform

# %%
df['SalePrice'] = np.log(df['SalePrice'])

# %%
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LotConfig  \
# 0   1          60         3         65.0     8450         3          4
# 1   2          20         3         80.0     9600         3          2
# 2   3          60         3         68.0    11250         0          4
# 3   4          70         3         60.0     9550         0          0
# 4   5          60         3         84.0    14260         0          2
#
#    Neighborhood  HouseStyle  OverallQual  ...  GarageType  GarageYrBlt  \
# 0             5           5            7  ...           1       2003.0
# 1            24           2            6  ...           1       1976.0
# 2             5           5            7  ...           1       2001.0
# 3             6           5            7  ...           5       1998.0
# 4            15           5            8  ...           1       2000.0
#
#    GarageFinish  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  MoSold  \
# ...

# %% [markdown]
# 2 . Linear model

# %%
from sklearn.model_selection import KFold,cross_val_score
from sklearn.linear_model import LinearRegression
x=df.drop('SalePrice',axis=1)
y=df['SalePrice']

model=LinearRegression()

kf=KFold(n_splits=5,shuffle=True)

scores=cross_val_score(model,x,y,cv=kf,scoring='r2')

print("scores for each fold:", scores)
print("Mean score:", np.mean(scores))
print("Min score:", np.min(scores))
print("Max score:", np.max(scores))
# Out:
# scores for each fold: [0.88655564 0.87966809 0.87542977 0.83788662 0.74755379]
# Mean score: 0.8454187823333488
# Min score: 0.7475537913378066
# Max score: 0.8865556371514751

# %%
from sklearn.model_selection import train_test_split
x=df.drop('SalePrice',axis=1)
y=df['SalePrice']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

model.fit(x_train,y_train)

y_pred_sk = model.predict(x_test)

from sklearn.metrics import mean_squared_error
J_mse_sk = mean_squared_error(y_pred_sk, y_test)

R_square_sk = model.score(x_test,y_test)
print('The Mean Square Error(MSE) or J(theta) is: ',J_mse_sk)
print('R square obtain for scikit learn library is :',R_square_sk)
# Out:
# The Mean Square Error(MSE) or J(theta) is:  0.016254493078348514
# R square obtain for scikit learn library is : 0.8947718262188245

# %%
f,ax = plt.subplots(1,2,figsize=(14,6))
import scipy as sp
_,(_,_,r)= sp.stats.probplot((y_test - y_pred_sk),fit=True,plot=ax[0])
ax[0].set_title('Multivariate Normality')

#Check for Homoscedasticity
sns.scatterplot(y = (y_test - y_pred_sk), x= y_pred_sk, ax = ax[1],color='r') 
ax[1].set_title('Homoscedasticity: \nResidual Vs Predicted')
# Out:
# Text(0.5, 1.0, 'Homoscedasticity: \nResidual Vs Predicted')

# %% [markdown]
# 3.1 Test dataset preproccess

# %%
test_df=pd.read_csv('test.csv')
test_df=test_df.drop('Id',axis=1)
test_df.drop(columns=columns_isnull,inplace=True)
test_df.drop(columns=cols_same,inplace=True)

test_categorical_col = []
for column in test_df.columns:
    if test_df[column].dtype == object:
        test_categorical_col.append(column)
test_categorical_col

test_label = LabelEncoder()
for col in test_categorical_col:
    test_df[col] = label.fit_transform(test_df[col])

test_columns_null=[i for i in test_df.columns if test_df[i].isnull().sum()>0]
test_columns_null

test_df.fillna(method='ffill',inplace=True)
test_df.head()
# Out:
# C:\Users\NoteBook\AppData\Local\Temp\ipykernel_10220\1427254835.py:19: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   test_df.fillna(method='ffill',inplace=True)
#    MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LotConfig  \
# 0          20         2         80.0    11622         3          4
# 1          20         3         81.0    14267         0          0
# 2          60         3         74.0    13830         0          4
# 3          60         3         78.0     9978         0          4
# 4         120         3         43.0     5005         0          4
#
#    Neighborhood  HouseStyle  OverallQual  OverallCond  ...  Fireplaces  \
# 0            12           2            5            6  ...           0
# 1            12           2            6            6  ...           0
# 2             8           4            5            5  ...           1
# ...

# %%
test_df=pd.read_csv('test.csv')
test_df=test_df.drop('Id',axis=1)

# %% [markdown]
# 3.2 Predict test data

# %%
y_test_pred=model.predict(test_df)
print(y_test_pred)

test_df['Predicted_SalePrice'] = y_test_pred
test_df.to_csv('predicted_prices.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\NoteBook\Desktop\Folders\AI\Projects\1\Untitled-1.ipynb Cell 29 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/NoteBook/Desktop/Folders/AI/Projects/1/Untitled-1.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> y_test_pred=model.predict(test_df)
#       <a href='vscode-notebook-cell:/c%3A/Users/NoteBook/Desktop/Folders/AI/Projects/1/Untitled-1.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> print(y_test_pred)
#       <a href='vscode-notebook-cell:/c%3A/Users/NoteBook/Desktop/Folders/AI/Projects/1/Untitled-1.ipynb#X40sZmlsZQ%3D%3D?line=3'>4</a> test_df['Predicted_SalePrice'] = y_test_pred
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
# ...

# %% [markdown]
# 4 . Other models

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Load and preprocess the data
df = pd.read_csv('train.csv')
columns_isnull = [i for i in df.columns if df[i].isnull().sum() > 600]
df.drop(columns=columns_isnull, inplace=True)

cols_same = []
for col in df.columns:
    most = df[col].mode()[0]
    count_col = (df[col] == most).sum()
    if count_col / len(df) > 0.8:
        cols_same.append(col)
df.drop(columns=cols_same, inplace=True)

categorical_col = [column for column in df.columns if df[column].dtype == object]
label = LabelEncoder()
for col in categorical_col:
    df[col] = label.fit_transform(df[col])

df.fillna(method='ffill', inplace=True)

# Split the data into training and testing sets
x = df.drop('SalePrice', axis=1)
y = df['SalePrice']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# Define the models and their parameter grids
models = { 
    'Ridge': {
        'model': Ridge(),
        'params': {
            'alpha': [0.1, 1, 10, 100],
            'fit_intercept': [True, False],
            
        }
    },
    'Lasso': {
        'model': Lasso(),
        'params': {
            'alpha': [0.1, 1, 10, 100],
            'fit_intercept': [True, False],
            
        }
    },
    'RandomForestRegressor': {
        'model': RandomForestRegressor(),
        'params': {
            'n_estimators': [10, 50, 100],
            'max_features': ['auto', 'sqrt', 'log2'],
            'max_depth': [None, 10, 20, 30]
        }
    }
}

# Use GridSearchCV to find the best model and parameters
scores = []
for model_name, mp in models.items():
    clf = GridSearchCV(mp['model'], mp['params'], cv=5, scoring='r2', return_train_score=False)
    clf.fit(x_train, y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })

best_model_info = max(scores, key=lambda x: x['best_score'])
best_model = models[best_model_info['model']]['model']
best_model.set_params(**best_model_info['best_params'])
best_model.fit(x_train, y_train)
y_pred = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = best_model.score(x_test, y_test)

print(f"Best Model: {best_model_info['model']}")
print(f"Best Parameters: {best_model_info['best_params']}")
print(f"The Mean Square Error(MSE) is: {mse}")
print(f"R square obtained is: {r2}")

# Optional: Plotting the actual vs predicted values
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title(f"{best_model_info['model']} - Actual vs Predicted Prices")
plt.show()
# Out:
# C:\Users\NoteBook\AppData\Local\Temp\ipykernel_10220\4136428987.py:29: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# C:\Users\NoteBook\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.010e+11, tolerance: 6.809e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\NoteBook\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.576e+11, tolerance: 6.510e+08
# ...
